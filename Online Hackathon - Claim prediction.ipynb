# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#      ID Agency    Agency Type Distribution Channel  \
# 0  2010    EPX  Travel Agency               Online
# 1  4245    EPX  Travel Agency               Online
# 2  9251    CWT  Travel Agency               Online
# 3  4754    EPX  Travel Agency               Online
# 4  8840    EPX  Travel Agency               Online
#
#                       Product Name  Duration  Destination  Net Sales  \
# 0                Cancellation Plan        61  PHILIPPINES       12.0
# 1                Cancellation Plan         4     MALAYSIA       17.0
# 2  Rental Vehicle Excess Insurance        26     THAILAND       19.8
# 3         2 way Comprehensive Plan        15    HONG KONG       27.0
# 4         2 way Comprehensive Plan        15     MALAYSIA       37.0
#
#    Commision (in value)  Age  Claim
# 0                  0.00   41      0
# 1                  0.00   35      0
# 2                 11.88   47      0
# 3                  0.00   48      0
# 4                  0.00   36      0

# %%
df['Claim'].value_counts()
# Out:
# 0    43590
# 1     8720
# Name: Claim, dtype: int64

# %%
df['Age'].plot(kind='box')

# %%
df['Commision (in value)'].describe()
# Out:
# count    52310.000000
# mean        12.219963
# std         22.847645
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         13.380000
# max        262.760000
# Name: Commision (in value), dtype: float64

# %%
df['Agency Type'].value_counts().plot(kind='bar')

# %%
df['Distribution Channel'].value_counts().plot(kind='pie')

# %%
df['Product Name'].value_counts().head(5).plot(kind='bar')

# %%
df['Duration'].plot(kind='box')

# %%
df['Duration'].median()
# Out:
# 24.0

# %%
df['Destination'].value_counts().head(10).plot(kind='bar')

# %%
df.groupby(['Destination', 'Claim']).describe()
# Out:
#                                         ID                                    \
#                                      count         mean          std     min
# Destination                  Claim
# ARGENTINA                    0        11.0  6097.636364  1854.480157  3535.0
#                              1         1.0  7418.000000          NaN  7418.0
# AUSTRALIA                    0      2556.0  6035.418232  2322.620432  2000.0
#                              1       455.0  5885.505495  2216.240161  2002.0
# AUSTRIA                      0        66.0  5861.181818  2307.823709  2008.0
# AZERBAIJAN                   0         6.0  3856.833333  1123.649664  2053.0
# BAHRAIN                      0        10.0  5989.800000  2270.510848  2886.0
# BANGLADESH                   0        66.0  5985.121212  2089.073519  2030.0
# BELARUS                      0         2.0  3978.500000   982.171319  3284.0
# BELGIUM                      0        32.0  5852.500000  2256.371466  2335.0
# ...

# %%
"""
1) Where do consumers travel the most
2) How does agency type impact the possibility of the consumers to claim 
3) Does a specific product (product name) has any influence over the claim
4) Does age play a role in the claim
5) Which destintions have highest ratio of claims
6) Understanding the variance
7) Understanding the covariance



"""
# Out:
# ''

# %%
np.linspace(.20,1,10)
# Out:
# array([0.2       , 0.28888889, 0.37777778, 0.46666667, 0.55555556,
#        0.64444444, 0.73333333, 0.82222222, 0.91111111, 1.        ])

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
iris = pd.DataFrame(datasets.load_iris()['data'])
iris.columns = datasets.load_iris()['feature_names']
target = datasets.load_iris()['target']

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x_train, x_test, y_train, y_test = train_test_split(iris, target)

# %%
def model_ranking(x_train, x_test,y_train, y_test):
    
    score = []
    model = []
    
    #SVM
    clf = svm.SVC(kernel='rbf').fit(x_train, y_train)
    pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    model.append('SVM')
    score.append(accuracy)
    
    
    #xgboost
    
    clf = XGBClassifier().fit(x_train, y_train)
    pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    model.append('XGBOOST')
    score.append(accuracy)
    
    
    
    #random forest 
    
    clf = RandomForestClassifier().fit(x_train, y_train)
    pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    model.append('Random Forest')
    score.append(accuracy)
    
    
    #knn
    
    clf = KNeighborsClassifier().fit(x_train, y_train)
    pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    model.append('K Nearest Neighbours')
    score.append(accuracy)
    
    
    #Logistic Regression
    
    clf = LogisticRegression().fit(x_train, y_train)
    pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    model.append('Logistic Regression')
    score.append(accuracy)
    
    my_dict = {k:v for k,v in zip(model, score)}
    
    results

    ky = list(results.keys())
    v = list(results.values())
    plt.barh(ky, v)
    
    print('\n\n')
    print(my_dict)
    
    
    return my_dict

# %%
results = model_ranking(x_train, x_test,y_train, y_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
results

ky = list(results.keys())
v = list(results.values())

# %%
plt.barh(ky, v)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar([1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-ae7e7a919334> in <module>
# ----> 1 plt.bar([1,2,3,4])
#
# TypeError: bar() missing 1 required positional argument: 'height'
